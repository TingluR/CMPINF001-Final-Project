# %% [markdown]
# # My Metric is Firearn Seizures dataset

# %%
import pandas as pd

df = pd.read_csv('Firearm_Seizures_Data.csv', index_col=0)
df
# Out:
#                                                 total_count  other_count  \
# address
# 300 BLOCK S NEGLEY AVE PITTSBURGH, PA 15206              55            0
# 1800 BLOCK FAIRLEE ST PITTSBURGH, PA 15212               44            3
# 1000 BLOCK SOUTH SIDE AVE PITTSBURGH, PA 15212           29            0
# 700 BLOCK N HOMEWOOD AVE PITTSBURGH, PA 15208            24            0
# 1600 BLOCK WORTHINGTON ST PITTSBURGH, PA 15206           19            1
# ...                                                     ...          ...
# 1600 BLOCK CENTRE AVE PITTSBURGH, PA 15219                1            0
# FULTON ST & HAMLIN ST PITTSBURGH, PA 15233                1            0
# 3800 BLOCK MC CLURE AVE PITTSBURGH, PA 15212              1            0
# 300 BLOCK LINNVIEW AVE PITTSBURGH, PA 15210               1            0
# 2100 BLOCK RHINE ST PITTSBURGH, PA 15212                  1            0
#
#                                                 pistol_count  revolver_count  \
# ...

# %%
total = df.groupby('neighborhood').agg(Firearm_Seizures = ('total_count', 'sum'))

total.sort_values("Firearm_Seizures", ascending=False).to_csv('TheFirearmS.csv')

total.sort_values("Firearm_Seizures", ascending=False)#.head(5)#True Faluse
#total.sort_values("Total", ascending=False).head(5)
# Out:
#                   Firearm_Seizures
# neighborhood
# Homewood South                 311
# South Side Flats               176
# Homewood North                 152
# East Liberty                   142
# Carrick                        139
# ...                            ...
# Oakwood                          4
# Summer Hill                      3
# Swisshelm Park                   3
# Mt. Oliver                       3
# Regent Square                    3
#
# [88 rows x 1 columns]

# %%
import matplotlib.pyplot as plot

total["neighborhood"] = total.index #index

total.plot.bar(x="neighborhood", y="Firearm_Seizures", rot=90,figsize=(20,10), title="Fire Inciden 2015-2022")
# Out:
# <AxesSubplot:title={'center':'Fire Inciden 2015-2022'}, xlabel='neighborhood'>

# %% [markdown]
# ### Conclusion: I use the Firearm Seizures Dataset. my measure is that the lowest total number of firearm seizures in a neighborhood between 2015 and 2022 means that the smaller this safety hazard is, the greater it is anyway.
